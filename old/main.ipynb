# %%
import os
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

from utils.data_utils import csvs_merge

mpl.style.use('default'); plt.rcParams['figure.figsize'] = [20, 20]; 
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Create folders for processed data and merge all .csv files of each bearing in FEMTO dataset.

# %%
files_info = {
    # file type identifier, columns name, columns to read.
    'acc'  : {'usecols' : [0, 1, 2, 4, 5], 'names' : ['hour', 'min', 'seg', 'h_acc', 'v_acc']},
    'temp' : {'usecols' : [0, 1, 2, 4],    'names' : ['hour', 'min', 'seg', 'temp']}
}

for bearing in os.listdir('data/original_data/femto_dataset/'):
    # Creating folders for processed data.
    os.mkdir('data/processed_data/%s' % (bearing))
    
    # Merging .csv files.
    csvs_merge(path = 'data/original_data/femto_dataset/%s' % (bearing), files_info, bearing)

# %% [markdown]
# ### Plotting some vibration data.

# %%
plt.plot(vib_data["B21"]["v_acc"])

# %%
plt.plot(vib_data["B31"]["v_acc"])

# %%
plt.plot(vib_data["B11"]["v_acc"])

# %% [markdown]
# ### Plotting cumsum and derivative.

# %%
# Plotting derv.
for condition in cumsum_v.keys():
    fig, ax = plt.subplots(2, 1)
    
    [ax[0].plot(x) for x in cumsum_v[condition]]
    [ax[1].plot(x) for x in derv_v[condition]]

    ax[0].grid(); ax[1].grid(); 
    fig.tight_layout()

#ax.set_ylim(0, 0.15*10**7)

# %%
pca = PCA(n_components = 1)

x = StandardScaler().fit_transform(np.array(vib_cumsum_v['1'][0]).reshape(-1, 1))
principalComponents = pca.fit_transform(x)
plt.plot(principalComponents)

# %%
# %debug
# Out:
# > <ipython-input-18-f2c8a3f495fc>(16)<module>()
#      14
#      15 for thread in thread_list:
# ---> 16     thread.start()
#      17 for thread in thread_list:
#      18      thread.join()
# ---------------------------------------------------------------------------
# StdinNotImplementedError                  Traceback (most recent call last)
# <ipython-input-19-bc99e4ec804d> in <module>
# ----> 1 get_ipython().run_line_magic('debug', '')
#
# ~/.local/lib/python3.7/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2312                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2313             with self.builtin_trap:
# -> 2314                 result = fn(*args, **kwargs)
#    2315             return result
#    2316
#
# </home/az/.local/lib/python3.7/site-packages/decorator.py:decorator-gen-57> in debug(self, line, cell)
#
# ~/.local/lib/python3.7/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
# ...
